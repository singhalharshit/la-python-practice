# %%
import pandas as pd


df= pd.read_excel(r'E:/Coding Practice/la-python-practice/data_testing/Dress Sales.xlsx') #To read data from an excel file if i were to use csv file you can simply use pd.read_csv and so on
df

# It can run without r also but just for the safe side we use r for the windows OS
# One might need to install openpyxl in order to read excel file of the latest version
# Make sure to switch between \ and / which works when
# Out:
#        Dress_ID  29/8/2013  31/8/2013  2013-02-09 00:00:00  \
# 0    1006032852       2114       2274                 2491
# 1    1212192089        151        275                  570
# 2    1190380701          6          7                    7
# 3     966005983       1005       1128                 1326
# 4     876339541        996       1175                 1304
# ..          ...        ...        ...                  ...
# 495   713391965          0          0                    0
# 496   722565148          0          0                    0
# 497   532874347          0          0                    0
# 498   655464934          0          0                    0
# 499   919930954          0          0                    0
#
#      2013-04-09 00:00:00  2013-06-09 00:00:00  2013-08-09 00:00:00  \
# 0                   2660                 2727                 2887
# 1                    750                  813                 1066
# ...

# %%
type(df)

# Like in SQL we have Table in pandas we have dataframe so table and dataframe are almost equivalent to eachother
# Out:
# pandas.core.frame.DataFrame

# %%
reading_data_from_different_sheet = pd.read_excel(r'E:/Coding Practice/la-python-practice/data_testing/Dress Sales.xlsx',sheet_name="Sheet2")
reading_data_from_different_sheet

# By default pandas read data from first sheet but I want to make it read data from any other sheet we can do it this way. It has an option of passing sheet_name to read data from the specified sheet name
# Out:
#    Id Student Name  Student Number
# 0   1          ABC       987654321

# %%
df.head() # To call top 5 rows
df.tail() # To call last 5 rows
# Out:
#       Dress_ID  29/8/2013  31/8/2013  2013-02-09 00:00:00  \
# 495  713391965          0          0                    0
# 496  722565148          0          0                    0
# 497  532874347          0          0                    0
# 498  655464934          0          0                    0
# 499  919930954          0          0                    0
#
#      2013-04-09 00:00:00  2013-06-09 00:00:00  2013-08-09 00:00:00  \
# 495                  560                  554                  544
# 496                  875                  866                  861
# 497                  734                  728                  726
# 498                  254                  259                  261
# 499                  538                  545                  558
#
#      2013-10-09 00:00:00 2013-12-09 00:00:00 14/9/2013  ... 24/9/2013  \
# 495                  537                 525       519  ...       400
# ...

# %%
# If a csv file is being seperated by any other separator say for an example the data is being separated by @ then we can call it as pd.read_csv(<File Path>, sep= '@')
# If we don't want to include the bydefault header we can use it by pd.read_excel(<File Path>, header= None) and if we want to give column name of our wish then we can do it same by
# pd.read_excel(<File Path>. header = None, names=['A','B','C']) or whatsoever we wanna give
# We can even call a HTML Page by simply using pd.read_html(<Website Link>)
